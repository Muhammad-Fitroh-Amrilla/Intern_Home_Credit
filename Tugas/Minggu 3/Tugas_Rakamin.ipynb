# %%
# import library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading dataset
url = '/content/drive/MyDrive/Dataset AI/Marketing_Campaign_Data_A-21492758-f47a-4913-971e-68c9a721311a.csv'
df = pd.read_csv(url)
df
# Out:
#        Unnamed: 0  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           58785       0         Cash loans           F            Y
# 1          166116       0         Cash loans           F            N
# 2          170111       0         Cash loans           F            Y
# 3          184247       0         Cash loans           F            N
# 4           75886       0         Cash loans           M            Y
# ...           ...     ...                ...         ...          ...
# 30717      183150       1         Cash loans           F            N
# 30718      192611       0         Cash loans           F            N
# 30719       50975       0         Cash loans           F            Y
# 30720       71489       0         Cash loans           F            N
# 30721       96406       0         Cash loans           F            Y
#
#       FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                   Y          157500.0    225000.0      11781.0
# 1                   Y          180000.0    508495.5      21672.0
# 2                   Y          360000.0    639396.0      47934.0
# 3                   Y          162000.0    254700.0      14751.0
# 4                   Y          225000.0    787131.0      42066.0
# ...               ...               ...         ...          ...
# 30717               N          112500.0    275040.0      12951.0
# 30718               N          112500.0    553500.0      17851.5
# 30719               N          225000.0    254700.0      24939.0
# 30720               Y          315000.0   1762110.0      46480.5
# 30721               N           90000.0    568800.0      15133.5
#
#        AMT_GOODS_PRICE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  \
# 0             225000.0  Secondary / secondary special  House / apartment
# 1             454500.0  Secondary / secondary special  House / apartment
# 2             571500.0              Incomplete higher  House / apartment
# 3             225000.0               Higher education  House / apartment
# 4             679500.0               Higher education  House / apartment
# ...                ...                            ...                ...
# 30717         180000.0  Secondary / secondary special  House / apartment
# 30718         553500.0  Secondary / secondary special  House / apartment
# 30719         225000.0  Secondary / secondary special  House / apartment
# 30720        1575000.0  Secondary / secondary special  House / apartment
# 30721         450000.0               Higher education  House / apartment
#
#        REGION_POPULATION_RELATIVE  REGION_RATING_CLIENT_W_CITY  \
# 0                        0.014520                            2
# 1                        0.031329                            2
# 2                        0.032561                            1
# 3                        0.010147                            2
# 4                        0.025164                            2
# ...                           ...                          ...
# 30717                    0.018801                            2
# 30718                    0.018850                            2
# 30719                    0.006008                            2
# 30720                    0.072508                            1
# 30721                    0.010556                            3
#
#              APPL_DATETIME  DATE_BIRTH
# 0      2016-06-11 17:28:54  17-07-1959
# 1      2015-05-22 08:42:03  23-06-1951
# 2      2016-11-26 20:54:07  07-06-1979
# 3      2017-02-20 09:22:06  20-07-1958
# 4      2017-02-28 09:38:45  05-08-1985
# ...                    ...         ...
# 30717  2017-09-23 20:23:31  06-02-1953
# 30718  2018-01-08 22:57:45  14-06-1984
# 30719  2018-04-29 16:14:04  09-10-1980
# 30720  2017-11-05 03:03:21  13-12-1964
# 30721  2018-11-30 13:17:39  30-03-1961
#
# [30722 rows x 16 columns]

# %%
# Cek tipe data 
df.dtypes
# Out:
# Unnamed: 0                              int64
# TARGET                                  int64
# NAME_CONTRACT_TYPE                     object
# CODE_GENDER                            object
# FLAG_OWN_CAR                           object
# FLAG_OWN_REALTY                        object
# AMT_INCOME_TOTAL                      float64
# AMT_CREDIT                            float64
# AMT_ANNUITY                           float64
# AMT_GOODS_PRICE                       float64
# NAME_EDUCATION_TYPE                    object
# NAME_HOUSING_TYPE                      object
# REGION_POPULATION_RELATIVE            float64
# REGION_RATING_CLIENT_W_CITY             int64
# APPL_DATETIME                  datetime64[ns]
# DATE_BIRTH                             object
# age                                     int64
# dtype: object

# %%
# Menghitung Umur Customer 
from datetime import datetime
from datetime import date
def calculate_age(born):
    born = datetime.strptime(born, "%d-%m-%Y").date()
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

df['age'] = df['DATE_BIRTH'].apply(calculate_age)
df
# Out:
#        Unnamed: 0  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 21          95421       0         Cash loans           F            N
# 26         180539       0         Cash loans           F            N
# 78         110649       0         Cash loans           M            Y
# 84         133649       0         Cash loans           M            N
# 101        135876       0         Cash loans           F            N
# ...           ...     ...                ...         ...          ...
# 30681      195649       0         Cash loans           F            N
# 30690       88532       0         Cash loans           F            N
# 30700      119310       0         Cash loans           M            Y
# 30710       67004       0         Cash loans           F            N
# 30721       96406       0         Cash loans           F            Y
#
#       FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 21                  Y          135000.0    648000.0      33214.5
# 26                  Y          225000.0    545040.0      25537.5
# 78                  N          153000.0    360000.0      28440.0
# 84                  Y          121500.0    302206.5      16524.0
# 101                 Y          103500.0    161730.0       8901.0
# ...               ...               ...         ...          ...
# 30681               N          247500.0    398016.0      22977.0
# 30690               Y          225000.0    808650.0      23773.5
# 30700               Y          112500.0    634482.0      20596.5
# 30710               N           90000.0    123637.5       9909.0
# 30721               N           90000.0    568800.0      15133.5
#
#        AMT_GOODS_PRICE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  \
# 21            648000.0  Secondary / secondary special  House / apartment
# 26            450000.0  Secondary / secondary special  House / apartment
# 78            360000.0  Secondary / secondary special   Rented apartment
# 84            229500.0  Secondary / secondary special   Rented apartment
# 101           135000.0  Secondary / secondary special  House / apartment
# ...                ...                            ...                ...
# 30681         360000.0  Secondary / secondary special       With parents
# 30690         675000.0  Secondary / secondary special  House / apartment
# 30700         454500.0               Higher education  House / apartment
# 30710         112500.0  Secondary / secondary special  House / apartment
# 30721         450000.0               Higher education  House / apartment
#
#        REGION_POPULATION_RELATIVE  REGION_RATING_CLIENT_W_CITY  \
# 21                       0.018209                            3
# 26                       0.010500                            3
# 78                       0.010556                            3
# 84                       0.020713                            3
# 101                      0.006852                            3
# ...                           ...                          ...
# 30681                    0.006305                            3
# 30690                    0.018029                            3
# 30700                    0.020713                            3
# 30710                    0.020246                            3
# 30721                    0.010556                            3
#
#             APPL_DATETIME  DATE_BIRTH  age
# 21    2017-04-22 14:25:01  13-12-1949   72
# 26    2018-05-26 00:05:43  28-07-1993   29
# 78    2018-07-01 03:34:13  23-06-1952   70
# 84    2017-03-04 19:28:13  04-04-1960   62
# 101   2018-04-03 04:52:48  07-01-1974   48
# ...                   ...         ...  ...
# 30681 2017-01-09 04:18:02  29-06-1964   58
# 30690 2017-09-29 09:21:55  12-07-1960   62
# 30700 2017-11-07 20:48:19  21-04-1990   32
# 30710 2017-09-23 10:41:38  28-01-1995   27
# 30721 2018-11-30 13:17:39  30-03-1961   61
#
# [2182 rows x 17 columns]

# %%
# Mengategorikan customer sesuai umur
conditions = [
     (df.age < 20),
     (df.age >=20 )&(df.age<30),
     (df.age>=30)&(df.age<40),
     (df.age>=40)&(df.age<50),
     (df.age>=50)&(df.age<60),
     (df.age>=60)
]

values = ['Late_Ten', 'Twenty', 'Thirty', 'Fourty', 'Fifty', 'Above_Sixty']

df['Kategori_Umur']=np.select(conditions,values)

# %%
# Memfilter dataset dengan target = 0, rating = 3 dan appl_datetime antara 1 Januari 2017 sampai 31 Desember 2018
df.APPL_DATETIME = pd.to_datetime(df.APPL_DATETIME)
df2 = df[(df.TARGET ==0)&(df.REGION_RATING_CLIENT_W_CITY==3)&(df.APPL_DATETIME.between('2017-1-1','2018-12-31'))]
df2
# Out:
#        Unnamed: 0  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 21          95421       0         Cash loans           F            N
# 26         180539       0         Cash loans           F            N
# 78         110649       0         Cash loans           M            Y
# 84         133649       0         Cash loans           M            N
# 101        135876       0         Cash loans           F            N
# ...           ...     ...                ...         ...          ...
# 30681      195649       0         Cash loans           F            N
# 30690       88532       0         Cash loans           F            N
# 30700      119310       0         Cash loans           M            Y
# 30710       67004       0         Cash loans           F            N
# 30721       96406       0         Cash loans           F            Y
#
#       FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 21                  Y          135000.0    648000.0      33214.5
# 26                  Y          225000.0    545040.0      25537.5
# 78                  N          153000.0    360000.0      28440.0
# 84                  Y          121500.0    302206.5      16524.0
# 101                 Y          103500.0    161730.0       8901.0
# ...               ...               ...         ...          ...
# 30681               N          247500.0    398016.0      22977.0
# 30690               Y          225000.0    808650.0      23773.5
# 30700               Y          112500.0    634482.0      20596.5
# 30710               N           90000.0    123637.5       9909.0
# 30721               N           90000.0    568800.0      15133.5
#
#        AMT_GOODS_PRICE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  \
# 21            648000.0  Secondary / secondary special  House / apartment
# 26            450000.0  Secondary / secondary special  House / apartment
# 78            360000.0  Secondary / secondary special   Rented apartment
# 84            229500.0  Secondary / secondary special   Rented apartment
# 101           135000.0  Secondary / secondary special  House / apartment
# ...                ...                            ...                ...
# 30681         360000.0  Secondary / secondary special       With parents
# 30690         675000.0  Secondary / secondary special  House / apartment
# 30700         454500.0               Higher education  House / apartment
# 30710         112500.0  Secondary / secondary special  House / apartment
# 30721         450000.0               Higher education  House / apartment
#
#        REGION_POPULATION_RELATIVE  REGION_RATING_CLIENT_W_CITY  \
# 21                       0.018209                            3
# 26                       0.010500                            3
# 78                       0.010556                            3
# 84                       0.020713                            3
# 101                      0.006852                            3
# ...                           ...                          ...
# 30681                    0.006305                            3
# 30690                    0.018029                            3
# 30700                    0.020713                            3
# 30710                    0.020246                            3
# 30721                    0.010556                            3
#
#             APPL_DATETIME  DATE_BIRTH  age Kategori_Umur
# 21    2017-04-22 14:25:01  13-12-1949   72   Above_Sixty
# 26    2018-05-26 00:05:43  28-07-1993   29        Twenty
# 78    2018-07-01 03:34:13  23-06-1952   70   Above_Sixty
# 84    2017-03-04 19:28:13  04-04-1960   62   Above_Sixty
# 101   2018-04-03 04:52:48  07-01-1974   48        Fourty
# ...                   ...         ...  ...           ...
# 30681 2017-01-09 04:18:02  29-06-1964   58         Fifty
# 30690 2017-09-29 09:21:55  12-07-1960   62   Above_Sixty
# 30700 2017-11-07 20:48:19  21-04-1990   32        Thirty
# 30710 2017-09-23 10:41:38  28-01-1995   27        Twenty
# 30721 2018-11-30 13:17:39  30-03-1961   61   Above_Sixty
#
# [2182 rows x 18 columns]

# %%
# mneghitung jumlah customer per kategori umur
df2['Kategori_Umur'].value_counts()
# Out:
# Above_Sixty    897
# Fifty          428
# Thirty         380
# Fourty         277
# Twenty         200
# Name: Kategori_Umur, dtype: int64

# %% [markdown]
# jawaban :
#
#
# *   Soal 1 : Above_sixty
# *   Soal 2 : Fifty
# *   Soal 3 : Thirty
